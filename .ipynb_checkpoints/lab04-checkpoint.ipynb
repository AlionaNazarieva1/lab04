# %%
import numpy as np
import math
from scipy.integrate import odeint
import matplotlib.pyplot as plt
w = 5.5
g = 4.4
t0 = 0
tmax = 55
dt = 0.05
def f(t):
    f = 2.2*math.sin(4*t)
    return f
def dy(s,t):
    dy1 =  s[1]
    dy2 =  -w*w*s[0] - g*s[1] - f(t)
    return [dy1, dy2]
t = np.arange(t0,tmax,dt) 
v0=[1.1,0]
s = odeint(dy,v0,t)
plt.plot(t,s,'r--', linewidth=2.0,label="решение")
plt.grid()
plt.show()
x1=np.array(s)
plt.plot(x1[:,0],x1[:,1],'r--', linewidth=2.0,label="фазовый портрет")
plt.legend()
plt.grid()
plt.show()

# %%
x1=np.array(s)
plt.plot(x1[:,0],x1[:,1],'r--', linewidth=2.0,label="фазовый портрет")
plt.legend()
plt.grid()
plt.show()
# Out:
# array([[ 1.1       ,  0.        ],
#        [ 1.06136281, -1.48485147],
#        [ 0.95776952, -2.59546218],
#        ...,
#        [ 0.09576322, -0.06540555],
#        [ 0.09060581, -0.14020266],
#        [ 0.08183623, -0.20941034]])

# %%
plt.plot(x1[:,0],x1[:,1],'r--', linewidth=2.0,label="фазовый портрет")
plt.legend()
plt.grid()
plt.show()
